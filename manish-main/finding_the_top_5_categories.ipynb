# %% [markdown]
# <a href="https://colab.research.google.com/github/kosgilavanya/lavanya/blob/main/finding_the_top_5_categories.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
con=pd.read_csv('/content/Content (1).csv')

# %%
rt=pd.read_csv('/content/ReactionTypes (1).csv')

# %%
r=pd.read_csv('/content/Reactions (2).csv')

# %%
con.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2           2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3           3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4           4  01ab84dd-6364-4236-abbb-3f237db77180
#
#                                 User ID   Type        Category  \
# 0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo        Studying
# 1  beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo  healthy eating
# 2  a5c65404-5894-4b87-82f2-d787cbee86b4  photo  healthy eating
# 3  9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo      technology
# 4  e206e31b-5f85-4964-b6ea-d7ee5324def1  video            food
#
#                                                  URL
# 0  https://socialbuzz.cdn.com/content/storage/975...
# 1  https://socialbuzz.cdn.com/content/storage/9f7...
# 2  https://socialbuzz.cdn.com/content/storage/230...
# 3  https://socialbuzz.cdn.com/content/storage/356...
# ...

# %%
con=con.drop(columns='URL',axis=1)

# %%
con.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2           2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3           3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4           4  01ab84dd-6364-4236-abbb-3f237db77180
#
#                                 User ID   Type        Category
# 0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo        Studying
# 1  beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo  healthy eating
# 2  a5c65404-5894-4b87-82f2-d787cbee86b4  photo  healthy eating
# 3  9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo      technology
# 4  e206e31b-5f85-4964-b6ea-d7ee5324def1  video            food

# %%
con.isnull().sum()
# Out:
# Unnamed: 0    0
# Content ID    0
# User ID       0
# Type          0
# Category      0
# dtype: int64

# %%
con['Category'].value_counts()
# Out:
# technology           71
# animals              67
# travel               67
# culture              63
# science              63
# fitness              61
# food                 61
# healthy eating       61
# cooking              60
# soccer               58
# tennis               58
# education            57
# dogs                 56
# studying             55
# veganism             48
# public speaking      48
# Fitness               5
# Animals               4
# Science               4
# "soccer"              3
# "culture"             3
# Soccer                3
# "dogs"                2
# Education             2
# Studying              2
# Travel                2
# Food                  2
# "veganism"            1
# "public speaking"     1
# Public Speaking       1
# "technology"          1
# "cooking"             1
# Healthy Eating        1
# "studying"            1
# "food"                1
# Culture               1
# "tennis"              1
# Technology            1
# ...

# %%
con.replace({'Category':{'"soccer"':'soccer','"culture"':'culture','"dogs"':'dogs','"veganism"':'veganism','"public speaking"':'public speaking','"technology"':'technology','"cooking"':'cooking','"animals"':'animals','"food"':'food','"studying"':'studying','"science"':'science'}},inplace=True)

# %%
con['Category'].value_counts()
# Out:
# technology         72
# animals            68
# travel             67
# culture            66
# science            64
# food               62
# cooking            61
# soccer             61
# fitness            61
# healthy eating     61
# dogs               58
# tennis             58
# education          57
# studying           56
# public speaking    49
# veganism           49
# Fitness             5
# Science             4
# Animals             4
# Soccer              3
# Food                2
# Studying            2
# Education           2
# Travel              2
# Technology          1
# "tennis"            1
# Culture             1
# Healthy Eating      1
# Veganism            1
# Public Speaking     1
# Name: Category, dtype: int64

# %%
con.rename(columns={'Type':'content_type'},inplace=True)

# %%
con.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2           2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3           3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4           4  01ab84dd-6364-4236-abbb-3f237db77180
#
#                                 User ID content_type        Category
# 0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo        Studying
# 1  beb1f34e-7870-46d6-9fc7-2e12eb83ce43        photo  healthy eating
# 2  a5c65404-5894-4b87-82f2-d787cbee86b4        photo  healthy eating
# 3  9fb4ce88-fac1-406c-8544-1a899cee7aaf        photo      technology
# 4  e206e31b-5f85-4964-b6ea-d7ee5324def1        video            food

# %%
r.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2           2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3           3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4           4  97522e57-d9ab-4bd6-97bf-c24d952602d2
#
#                                 User ID     Type             Datetime
# 0                                   NaN      NaN  2021-04-22 15:17:15
# 1  5d454588-283d-459d-915d-c48a2cb4c27f  disgust  2020-11-07 09:43:50
# 2  92b87fa5-f271-43e0-af66-84fac21052e6  dislike  2021-06-17 12:22:51
# 3  163daa38-8b77-48c9-9af6-37a6c1447ac2   scared  2021-04-18 05:13:58
# 4  34e8add9-0206-47fd-a501-037b994650a2  disgust  2021-01-06 19:13:01

# %%
r.isnull().sum()
# Out:
# Unnamed: 0       0
# Content ID       0
# User ID       3019
# Type           980
# Datetime         0
# dtype: int64

# %%
r.dropna(inplace=True)

# %%
r.isnull().sum()
# Out:
# Unnamed: 0    0
# Content ID    0
# User ID       0
# Type          0
# Datetime      0
# dtype: int64

# %%
r.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 1           1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2           2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3           3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4           4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 5           5  97522e57-d9ab-4bd6-97bf-c24d952602d2
#
#                                 User ID        Type             Datetime
# 1  5d454588-283d-459d-915d-c48a2cb4c27f     disgust  2020-11-07 09:43:50
# 2  92b87fa5-f271-43e0-af66-84fac21052e6     dislike  2021-06-17 12:22:51
# 3  163daa38-8b77-48c9-9af6-37a6c1447ac2      scared  2021-04-18 05:13:58
# 4  34e8add9-0206-47fd-a501-037b994650a2     disgust  2021-01-06 19:13:01
# 5  9b6d35f9-5e15-4cd0-a8d7-b1f3340e02c4  interested  2020-08-23 12:25:58

# %%
r=r.drop(columns='User ID',axis=1)

# %%
r.head()
# Out:
#    Unnamed: 0                            Content ID        Type  \
# 1           1  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust
# 2           2  97522e57-d9ab-4bd6-97bf-c24d952602d2     dislike
# 3           3  97522e57-d9ab-4bd6-97bf-c24d952602d2      scared
# 4           4  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust
# 5           5  97522e57-d9ab-4bd6-97bf-c24d952602d2  interested
#
#               Datetime
# 1  2020-11-07 09:43:50
# 2  2021-06-17 12:22:51
# 3  2021-04-18 05:13:58
# 4  2021-01-06 19:13:01
# 5  2020-08-23 12:25:58

# %%
r.tail()
# Out:
#        Unnamed: 0                            Content ID       Type  \
# 25547       25547  75d6b589-7fae-4a6d-b0d0-752845150e56    worried
# 25548       25548  75d6b589-7fae-4a6d-b0d0-752845150e56    dislike
# 25549       25549  75d6b589-7fae-4a6d-b0d0-752845150e56  intrigued
# 25551       25551  75d6b589-7fae-4a6d-b0d0-752845150e56    worried
# 25552       25552  75d6b589-7fae-4a6d-b0d0-752845150e56    cherish
#
#                   Datetime
# 25547  2020-10-31 04:50:14
# 25548  2020-06-27 09:46:48
# 25549  2021-02-16 17:17:02
# 25551  2020-11-04 20:08:31
# 25552  2021-01-04 04:55:11

# %%
con=con.drop(columns='User ID',axis=1)

# %%
con.head()
# Out:
#    Unnamed: 0                            Content ID content_type  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo
# 1           1  9f737e0a-3cdd-4d29-9d24-753f4e3be810        photo
# 2           2  230c4e4d-70c3-461d-b42c-ec09396efb3f        photo
# 3           3  356fff80-da4d-4785-9f43-bc1261031dc6        photo
# 4           4  01ab84dd-6364-4236-abbb-3f237db77180        video
#
#          Category
# 0        Studying
# 1  healthy eating
# 2  healthy eating
# 3      technology
# 4            food

# %%
con.tail()
# Out:
#      Unnamed: 0                            Content ID content_type  \
# 995         995  b4cef9ef-627b-41d7-a051-5961b0204ebb        video
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c          GIF
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b        audio
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7          GIF
# 999         999  75d6b589-7fae-4a6d-b0d0-752845150e56        audio
#
#             Category
# 995  public speaking
# 996       technology
# 997         veganism
# 998          culture
# 999       technology

# %%
rt.head()
# Out:
#    Unnamed: 0        Type Sentiment  Score
# 0           0       heart  positive     60
# 1           1        want  positive     70
# 2           2     disgust  negative      0
# 3           3        hate  negative      5
# 4           4  interested  positive     30

# %%
rt['Type'].value_counts()
# Out:
# heart          1
# want           1
# disgust        1
# hate           1
# interested     1
# indifferent    1
# love           1
# super love     1
# cherish        1
# adore          1
# like           1
# dislike        1
# intrigued      1
# peeking        1
# scared         1
# worried        1
# Name: Type, dtype: int64

# %%
r=r.drop(columns='Unnamed: 0',axis=1)

# %%
r['Type'].value_counts()
# Out:
# heart          1497
# peeking        1438
# scared         1436
# adore          1427
# interested     1425
# hate           1420
# love           1411
# disgust        1406
# dislike        1396
# want           1396
# super love     1393
# like           1391
# indifferent    1385
# cherish        1380
# worried        1379
# intrigued      1354
# Name: Type, dtype: int64

# %%
con=con.drop(columns='Unnamed: 0',axis=1)

# %%
rt=rt.drop(columns='Unnamed: 0',axis=1)

# %%
new1=pd.merge(r,con,on='Content ID')

# %%
new1
# Out:
#                                  Content ID        Type             Datetime  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust  2020-11-07 09:43:50
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2     dislike  2021-06-17 12:22:51
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2      scared  2021-04-18 05:13:58
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust  2021-01-06 19:13:01
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2  interested  2020-08-23 12:25:58
# ...                                     ...         ...                  ...
# 22529  75d6b589-7fae-4a6d-b0d0-752845150e56     worried  2020-10-31 04:50:14
# 22530  75d6b589-7fae-4a6d-b0d0-752845150e56     dislike  2020-06-27 09:46:48
# 22531  75d6b589-7fae-4a6d-b0d0-752845150e56   intrigued  2021-02-16 17:17:02
# 22532  75d6b589-7fae-4a6d-b0d0-752845150e56     worried  2020-11-04 20:08:31
# 22533  75d6b589-7fae-4a6d-b0d0-752845150e56     cherish  2021-01-04 04:55:11
#
#       content_type    Category
# ...

# %%
new1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22534 entries, 0 to 22533
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Content ID    22534 non-null  object
#  1   Type          22534 non-null  object
#  2   Datetime      22534 non-null  object
#  3   content_type  22534 non-null  object
#  4   Category      22534 non-null  object
# dtypes: object(5)
# memory usage: 1.0+ MB

# %%
new1['Datetime']=pd.to_datetime(new1['Datetime'],format='%Y-%m-%d')

# %%
new1.head()
# Out:
#                              Content ID        Type            Datetime  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust 2020-11-07 09:43:50
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2     dislike 2021-06-17 12:22:51
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2      scared 2021-04-18 05:13:58
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust 2021-01-06 19:13:01
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2  interested 2020-08-23 12:25:58
#
#   content_type  Category
# 0        photo  Studying
# 1        photo  Studying
# 2        photo  Studying
# 3        photo  Studying
# 4        photo  Studying

# %%
new1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22534 entries, 0 to 22533
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Content ID    22534 non-null  object
#  1   Type          22534 non-null  object
#  2   Datetime      22534 non-null  datetime64[ns]
#  3   content_type  22534 non-null  object
#  4   Category      22534 non-null  object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 1.0+ MB

# %%
new1['Datetime']=new1['Datetime'].dt.date

# %%
new1.head()
# Out:
#                              Content ID        Type    Datetime content_type  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust  2020-11-07        photo
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2     dislike  2021-06-17        photo
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2      scared  2021-04-18        photo
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust  2021-01-06        photo
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2  interested  2020-08-23        photo
#
#    Category
# 0  Studying
# 1  Studying
# 2  Studying
# 3  Studying
# 4  Studying

# %%
new1['Datetime'].value_counts()
# Out:
# 2021-05-24    90
# 2021-01-11    90
# 2021-02-26    86
# 2020-06-27    85
# 2021-03-12    82
#               ..
# 2020-11-22    43
# 2021-05-14    40
# 2020-08-08    39
# 2020-06-18    37
# 2021-06-18    28
# Name: Datetime, Length: 366, dtype: int64

# %%
new1['Category'].value_counts()
# Out:
# animals            1653
# healthy eating     1566
# technology         1554
# science            1540
# cooking            1525
# culture            1501
# travel             1483
# food               1473
# soccer             1279
# education          1278
# dogs               1227
# tennis             1218
# studying           1210
# fitness            1158
# veganism           1136
# public speaking    1087
# Fitness             126
# Science             106
# Animals              85
# Food                 83
# Soccer               60
# Studying             41
# Culture              37
# Education            33
# Public Speaking      29
# Travel               27
# Veganism             10
# Healthy Eating        6
# Technology            3
# Name: Category, dtype: int64

# %%
new2=pd.merge(new1,rt,on='Type')

# %%
new2
# Out:
#                                  Content ID     Type    Datetime content_type  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2  disgust  2020-11-07        photo
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2  disgust  2021-01-06        photo
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2  disgust  2021-04-09        photo
# 3      9f737e0a-3cdd-4d29-9d24-753f4e3be810  disgust  2021-03-28        photo
# 4      230c4e4d-70c3-461d-b42c-ec09396efb3f  disgust  2020-08-04        photo
# ...                                     ...      ...         ...          ...
# 22529  435007a5-6261-4d8b-b0a4-55fdc189754b    adore  2020-10-04        audio
# 22530  435007a5-6261-4d8b-b0a4-55fdc189754b    adore  2020-09-18        audio
# 22531  4e4c9690-c013-4ee7-9e66-943d8cbd27b7    adore  2020-10-31          GIF
# 22532  4e4c9690-c013-4ee7-9e66-943d8cbd27b7    adore  2020-06-25          GIF
# 22533  4e4c9690-c013-4ee7-9e66-943d8cbd27b7    adore  2020-12-17          GIF
#
# ...

# %%
datt=new2[['Datetime']]

# %%
datt
# Out:
#          Datetime
# 0      2020-11-07
# 1      2021-01-06
# 2      2021-04-09
# 3      2021-03-28
# 4      2020-08-04
# ...           ...
# 22529  2020-10-04
# 22530  2020-09-18
# 22531  2020-10-31
# 22532  2020-06-25
# 22533  2020-12-17
#
# [22534 rows x 1 columns]

# %%
datt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22534 entries, 0 to 22533
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Datetime  22534 non-null  object
# dtypes: object(1)
# memory usage: 868.1+ KB

# %%
datt['Datetime']=pd.to_datetime(datt['Datetime'],format='%Y-%m-%d')
# Out:
# <ipython-input-103-82a15ac65add>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datt['Datetime']=pd.to_datetime(datt['Datetime'],format='%Y-%m-%d')

# %%
datt['month']=datt['Datetime'].dt.month
# Out:
# <ipython-input-104-fb7152f5478a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datt['month']=datt['Datetime'].dt.month

# %%
datt
# Out:
#         Datetime  month
# 0     2020-11-07     11
# 1     2021-01-06      1
# 2     2021-04-09      4
# 3     2021-03-28      3
# 4     2020-08-04      8
# ...          ...    ...
# 22529 2020-10-04     10
# 22530 2020-09-18      9
# 22531 2020-10-31     10
# 22532 2020-06-25      6
# 22533 2020-12-17     12
#
# [22534 rows x 2 columns]

# %%
datt['month'].value_counts()
# Out:
# 5     1954
# 1     1949
# 8     1945
# 12    1941
# 10    1889
# 7     1884
# 11    1866
# 9     1862
# 3     1857
# 6     1836
# 4     1801
# 2     1750
# Name: month, dtype: int64

# %%
mdf=datt[['month']]

# %%
mdf['count']=1

# %%
mdf
# Out:
#        month  count
# 0         11      1
# 1          1      1
# 2          4      1
# 3          3      1
# 4          8      1
# ...      ...    ...
# 22529     10      1
# 22530      9      1
# 22531     10      1
# 22532      6      1
# 22533     12      1
#
# [22534 rows x 2 columns]

# %%
mdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22534 entries, 0 to 22533
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   month   22534 non-null  int64
#  1   count   22534 non-null  int64
# dtypes: int64(2)
# memory usage: 1.0 MB

# %%
mdf=mdf.groupby('month').sum()

# %%
monthorder=mdf.sort_values(by=['count'],ascending=False)

# %%
monthorder
# Out:
#        count
# month
# 5       1954
# 1       1949
# 8       1945
# 12      1941
# 10      1889
# 7       1884
# 11      1866
# 9       1862
# 3       1857
# 6       1836
# 4       1801
# 2       1750

# %%
month=[5,1,8,12,10,7,11,9,3,6,4,2]

# %%
monthorder['month']=month

# %%
monthorder
# Out:
#        count  month
# month
# 5       1954      5
# 1       1949      1
# 8       1945      8
# 12      1941     12
# 10      1889     10
# 7       1884      7
# 11      1866     11
# 9       1862      9
# 3       1857      3
# 6       1836      6
# 4       1801      4
# 2       1750      2

# %%
plt.pie(monthorder['count'],labels=monthorder['month'],autopct='%0.3f%%')
plt.show()

# %%
new3=new2.drop(columns=['Content ID','Type','Datetime','content_type','Sentiment'])

# %%
new3.head()
# Out:
#          Category  Score
# 0        Studying      0
# 1        Studying      0
# 2        Studying      0
# 3  healthy eating      0
# 4  healthy eating      0

# %%
new3['Category']=new3['Category'].apply(str.lower)

# %%
new3
# Out:
#              Category  Score
# 0            studying      0
# 1            studying      0
# 2            studying      0
# 3      healthy eating      0
# 4      healthy eating      0
# ...               ...    ...
# 22529        veganism     72
# 22530        veganism     72
# 22531         culture     72
# 22532         culture     72
# 22533         culture     72
#
# [22534 rows x 2 columns]

# %%
new3.value_counts()
# Out:
# Category         Score
# animals          70       223
# culture          70       214
# food             70       211
# science          70       208
# technology       70       207
#                          ...
# veganism         45        61
# public speaking  35        60
# veganism         10        59
# public speaking  5         54
# dogs             12        53
# Length: 240, dtype: int64

# %%
new4=new3.groupby(['Category']).sum()

# %%
new4
# Out:
#                  Score
# Category
# animals          68624
# cooking          59174
# culture          60663
# dogs             48398
# education        52759
# fitness          50835
# food             61598
# healthy eating   63138
# public speaking  45751
# science          65405
# soccer           53216
# studying         49442
# technology       63035
# tennis           46185
# travel           59358
# veganism         45901

# %%
new4=new4.reset_index()

# %%
new4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  16 non-null     object
#  1   Score     16 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 384.0+ bytes

# %%
fig=plt.figure(figsize=(17,7))
plt.bar(new4['Category'],new4['Score'])
plt.show()

# %%
final=new4.sort_values(by=['Score'],ascending=False)

# %%
final
# Out:
#                  Score
# Category
# animals          68624
# science          65405
# healthy eating   63138
# technology       63035
# food             61598
# culture          60663
# travel           59358
# cooking          59174
# soccer           53216
# education        52759
# fitness          50835
# studying         49442
# dogs             48398
# tennis           46185
# veganism         45901
# public speaking  45751

# %%
final.head()
# Out:
#                 Score
# Category
# animals         68624
# science         65405
# healthy eating  63138
# technology      63035
# food            61598

# %%
type(final)
# Out:
# pandas.core.frame.DataFrame

# %%
newf=final[final.Score>=61598]

# %%
newf
# Out:
#                 Score
# Category
# animals         68624
# science         65405
# healthy eating  63138
# technology      63035
# food            61598

# %%
category=['animals','science','healthy eating','technology','food']
newf['category']=category
# Out:
# <ipython-input-141-652b8595fae6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newf['category']=category

# %%
newf
# Out:
#                 Score        category
# Category
# animals         68624         animals
# science         65405         science
# healthy eating  63138  healthy eating
# technology      63035      technology
# food            61598            food

# %%
plt.pie(newf['Score'],labels=newf['category'],autopct='%1.2f%%')
plt.show()
